# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#import mercury as mr # for widgets

# Replace 'file_name.txt' with the name of your txt file

df = pd.read_csv('C:\\Users\\Shahidul Saad\\Documents\\GitHub\\DashAppOline\\Nicolas03.7Data.txt',  header=None, na_values=[''], skipinitialspace=True)
df.dropna(inplace = True)

# Iterate through each column
for col in df.columns:
    Data =df[col].str.split(';', expand=True)

# #Data.columns = ['a', 'b']
Data.rename(columns = {1:'Odometer', 2:'Trip', 3:'Speed kmh', 4:'Is in Reverse', 5:'Riding Mode',  6:'MCU Current',  7:'BMS Current', 8:'Vehicle status byte1', 9:'Vehicle status byte2', 10:'Throttle',
                       11:'MCU Temp', 12:'Motor temp', 13:'Pack Voltage',  14:'BMS Cell Highest Voltage value', 15:'BMS Cell Lowest Voltage value', 16:'SOC', 17:'RPM', 18:'Avg MOSTFet temp',
                       19:'12V voltage', 20:'Charger Volt', 21:'Charger Current', 22:'Num Ative ERROR', 23:'Sum Active ERROR', 24:'Input Head light', 25:'Turn left', 26:'Turn Right', 27:'Mode Switch',
                       27:'Kick Stand', 28:'Kill switch', 29:'Key', 30:'Brake'}, inplace = True)
print(Data['Odometer'])
# Out:
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
#          ...
# 14164    55.20
# 14165    55.20
# 14166    55.20
# 14167    55.20
# 14168    55.20
# Name: Odometer, Length: 14169, dtype: object

# %% [markdown]
# Ploting the Pack voltage

# %%
plt.plot(Data['Pack Voltage'].astype(float))
plt.title('Pack Voltage ')
plt.xlabel('Time [S]')
plt.ylabel('Voltage [V]')
plt.show()

# %% [markdown]
# Ploting the current from the BMS

# %%
plt.plot(Data['BMS Current'].astype(float))
plt.title('BMS Current')
plt.xlabel('Time [S]')
plt.ylabel('Current [A]')
plt.show()

# %% [markdown]
# Plotting the phase current

# %%
plt.plot(Data['MCU Current'].astype(float))
plt.title('MCU Current')
plt.xlabel('Time [S]')
plt.ylabel('Current [A]')
plt.show()

# %% [markdown]
# Ploting the odometer values

# %%
plt.plot(Data['Odometer'].astype(float))
plt.title('Odometer ')
plt.xlabel('Time [S]')
plt.ylabel('Odometer [km]')
plt.show()

# %% [markdown]
# Speed of the vehicle

# %%
plt.plot(Data['Speed kmh'].astype(float))
plt.title('Speed ')
plt.xlabel('Time [S]')
plt.ylabel('Speed [kmh]')
plt.show()

# %% [markdown]
# RPM of the Vehicle

# %%
plt.plot(Data['RPM'].astype(float))
plt.title('RPM')
plt.xlabel('Time [S]')
plt.ylabel('RMP [rev/min]')
plt.show()

# %% [markdown]
# The Throttle Position

# %%
plt.plot(Data['Throttle'].astype(float))
plt.title('Throttle position  ')
plt.xlabel('Time [S]')
plt.ylabel('Percent')
plt.show()

# %% [markdown]
# The Motor temperature of the vehicle

# %%
plt.plot(Data['Motor temp'].astype(float))
plt.title('Motor Temperature ')
plt.xlabel('Time [S]')
plt.ylabel('Temp [C]')
plt.show()

# %% [markdown]
# Motor Controller or MCU temperature

# %%
plt.plot(Data['MCU Temp'].astype(float))
plt.title('MCU temperature ')
plt.xlabel('Time [S]')
plt.ylabel('Temperature [C]')
plt.show()

# %% [markdown]
# BMS Cell Highest Voltage value

# %%
plt.plot((Data['BMS Cell Highest Voltage value'].astype(float)+200)/100)
plt.title('BMS Cell Highest Voltage value ')
plt.xlabel('Time [S]')
plt.ylabel('Voltage [V]')
plt.show()

# %% [markdown]
# BMS Cell Lowest Voltage value

# %%
plt.plot((Data['BMS Cell Lowest Voltage value'].astype(float)+200)/100)
plt.title('BMS Cell Lowest Voltage value ')
plt.xlabel('Time [S]')
plt.ylabel('Voltage [V]')
plt.show()

# %% [markdown]
# Ploting the Pack SOC

# %%
plt.plot(Data['SOC'].astype(float))
plt.title('SOC')
plt.xlabel('Time [S]')
plt.ylabel('SOC [%]')
plt.show()

# %% [markdown]
# Ploting the 12V battery voltage

# %%
plt.plot(Data['12V voltage'].astype(float)/10) 
plt.title('12V voltage')
plt.xlabel('Time [S]')
plt.ylabel('Voltage [V]')
plt.show()

# %% [markdown]
# Ploting the riding mode of the vehicle

# %%
plt.plot(Data['Riding Mode'].astype(float))
plt.title('Riding Mode')
plt.xlabel('Time [S]')
plt.ylabel('Mode ')
plt.show()

# %% [markdown]
# Plotting the brake signal

# %%
plt.plot(Data['Brake'].astype(float))
plt.title('Brake signal')
plt.xlabel('Time [S]')
plt.ylabel('Braking')
plt.show()

# %% [markdown]
# Plotting the the Trip

# %%
plt.plot(Data['Trip'].astype(float))
plt.title('Trip')
plt.xlabel('Time [S]')
plt.ylabel('KM')
plt.show()

# %% [markdown]
# Plotting the IS in Reverse

# %%
plt.plot(Data['Is in Reverse'].astype(float))
plt.title('Reverse')
plt.xlabel('Time [S]')
plt.ylabel('Reverse [R]')
plt.show()

# %% [markdown]
# Plotting the Avg MOSTFet temp

# %%
plt.plot(Data['Avg MOSTFet temp'].astype(float))
plt.title('MOSTFet temp')
plt.xlabel('Time [S]')
plt.ylabel('Temp [C]')
plt.show()

# %% [markdown]
# Plotting the Charger Current

# %%
plt.plot(Data['Charger Current'].astype(float))
plt.title('Charger Current')
plt.xlabel('Time [S]')
plt.ylabel('Current [Amp]')
plt.show()

# %% [markdown]
# Plotting the Charger VOltage

# %%
plt.plot(Data['Charger Volt'].astype(float))
plt.title('Charger Voltage')
plt.xlabel('Time [S]')
plt.ylabel('Voltage [V]')
plt.show()

# %% [markdown]
# Plotting the Left Indicator

# %%
plt.plot(Data['Turn left'].astype(float))
plt.title('Turn left')
plt.xlabel('Time [S]')
plt.ylabel('Turn left [L]')
plt.show()

# %% [markdown]
# Plotting the Right Indicator

# %%
plt.plot(Data['Turn Right'].astype(float))
plt.title('Turn Right')
plt.xlabel('Time [S]')
plt.ylabel('Turn Right [R]')
plt.show()

# %% [markdown]
# Ploting the

# %% [markdown]
# Plotting the
